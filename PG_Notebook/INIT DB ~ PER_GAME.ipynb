# %% [markdown]
# # import

# %%
import sys
import os
import pandas as pd
import seaborn as sns
import numpy as np
from src.constants import MODEL_CONST
from src.init_DFs.per_game import PerGameInit
initPG = PerGameInit()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 6
#       4 import seaborn as sns
#       5 import numpy as np
# ----> 6 from .src.constants import MODEL_CONST
#       7 from .src.init_DFs.per_game import PerGameInit
#       8 initPG = PerGameInit()
#
# ImportError: attempted relative import with no known parent package

# %% [markdown]
# # configure

# %%
# Configure local variables
season = "all"
situation = "5on5"

# %%
# Configure PER_GAME_{SITUATION}_{SEASON}.csv
games = pd.read_csv(MODEL_CONST['CSV_DB_PATH'] + f"{season}/games_{season}.csv")
team_5on5 = pd.read_csv(MODEL_CONST['CSV_DB_PATH'] + f"{season}/team_x_game_{situation}_{season}.csv")
odds = pd.read_csv(MODEL_CONST['CSV_DB_PATH'] + f"{season}/odds_x_game_{season}.csv")

# merge team_{SIT}, games, odds
pg = pd.merge(team_5on5, games)
pg = pd.merge(pg, odds)

# create PER_GAME_{SITUATION}_{SEASON}.csv
pg = initPG.init_per_game(pg)
pg.to_csv(MODEL_CONST['CSV_TEMP_PATH'] + f'PER_GAME_{situation}_{season}.csv', header=True, index=False)

# create PER_GAME_BY_TEAM_{SITUATION}_{SEASON}.csv
pg_copy = pg.copy()
pg_teams = initPG.init_by_team(pg, pg_copy)
pg_teams.to_csv(MODEL_CONST['CSV_TEMP_PATH'] + f'PER_GAME_BY_TEAM_{situation}_{season}.csv', header=True, index=False)
pg_teams
# Out:
#                 game_id team opp_team  season      next_game_id  score  \
# 0      2014-10-08BOSPHI  PHI      BOS    2014  2014-10-09PHINJD      1
# 1      2014-10-08BOSPHI  BOS      PHI    2014  2014-10-09DETBOS      2
# 2      2014-10-08CGYVAN  CGY      VAN    2014  2014-10-09EDMCGY      2
# 3      2014-10-08CGYVAN  VAN      CGY    2014  2014-10-11VANEDM      4
# 4      2014-10-08LAKSJS  SJS      LAK    2014  2014-10-11SJSWPG      4
# ...                 ...  ...      ...     ...               ...    ...
# 21541  2023-04-13WSHNJD  NJD      WSH    2022                NA      5
# 21542  2023-04-14CBJBUF  CBJ      BUF    2022                NA      2
# 21543  2023-04-14CBJBUF  BUF      CBJ    2022                NA      5
# 21544  2023-04-14NSHCOL  COL      NSH    2022                NA      4
# 21545  2023-04-14NSHCOL  NSH      COL    2022                NA      3
#
#        opp_score  win  reg_win  overtime  ...  scoreAdjustedShotsAttempts  \
# ...

# %% [markdown]
# # test

# %%
## CHECK OUT DFs
#len(pg_teams[(pg_teams["win"] == 1)]) - len(pg_teams[(pg_teams["win"] == 0)])
    # should = 0
#len(pg_teams[((pg_teams["reg_win"] == 1) & (pg_teams["overtime"] == 1))])
    # should = 0
#pg

## see if equal to saved PER_GAME.csv
#pg_csv = pd.read_csv(MODEL_CONST['CSV_TEMP_PATH'] + f'PER_GAME_{situation}_{season}.csv')
#pg_old_csv = pd.read_csv(MODEL_CONST['CSV_DB_PATH'] + f"{season}/PER_GAME_{situation}_{season}.csv")
#pg_compare = pg_csv.compare(pg_old_csv)
#print(pg_compare)

## see if equal to saved PER_GAME_BY_TEAM.csv
pg_teams_csv = pd.read_csv(MODEL_CONST['CSV_TEMP_PATH'] + f'PER_GAME_BY_TEAM_{situation}_{season}.csv')
pg_teams_old_csv = pd.read_csv(MODEL_CONST['CSV_DB_PATH'] + f"{season}/PER_GAME_BY_TEAM_{situation}_{season}.csv")
pg_teams_compare = pg_teams_csv.compare(pg_teams_old_csv)
print(pg_teams_compare)

# %% [markdown]
# # export

# %%
## PER_GAME
#pg.to_csv(MODEL_CONST['CSV_DB_PATH'] + f'{season}/PER_GAME_{situation}_{season}.csv', header=True, index=False)
#os.remove(MODEL_CONST['CSV_TEMP_PATH'] + f'PER_GAME_{situation}_{season}.csv')

## PER_GAME_BY_TEAM
pg_teams.to_csv(MODEL_CONST['CSV_DB_PATH'] + f'{season}/PER_GAME_BY_TEAM_{situation}_{season}.csv', header=True, index=False)
os.remove(MODEL_CONST['CSV_TEMP_PATH'] + f'PER_GAME_BY_TEAM_{situation}_{season}.csv')
