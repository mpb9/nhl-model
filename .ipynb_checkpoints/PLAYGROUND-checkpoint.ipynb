# %%
# PYTHON IMPORTS
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb

from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score

plt.style.use('seaborn-v0_8-pastel')
palette = sns.color_palette('pastel')

# %%
# MY IMPORTS
from src.init_DFs.per_game import PerGameInit
from src.init_DFs.next_game import NextGameInit
from src.per_game_model import PerGameModel

pgInit = PerGameInit()
ngInit = NextGameInit()
pgModel = PerGameModel()

# %%
# LOCAL VARIABLES
csv_path = "C:/Users/Michael Beebe/OneDrive - University of North Carolina at Chapel Hill/Desktop/bet-nhl-data/"
db_env = "PER_GAME_BY_TEAM"
season = "all"
sit = "5on5"
csv_file = f"{db_env}_{sit}_{season}"

# %%
# IMPORT CSV
df = pd.read_csv(csv_path + f"{season}/{csv_file}.csv")
df['game_date'] = pd.to_datetime(df['game_date'])
# Out:
# 21546

# %%
# TEAM SPECIFIC (??)
df = df[(df["team"] == "CAR")]

# SEASON

# %%
df['game_date'] = pd.to_datetime(df['game_date'])
# Out:
# game_id                                object
# team                                   object
# opp_team                               object
# season                                  int64
# next_game_id                           object
#                                        ...
# xGoalsFromActualReboundsOfShots       float64
# reboundxGoals                         float64
# totalShotCredit                       float64
# scoreAdjustedTotalShotCredit          float64
# scoreFlurryAdjustedTotalShotCredit    float64
# Length: 117, dtype: object

# %%
df.plot(x='game_date', y='xGoalsPercentage',
        style='.',
        figsize=(15, 5),
        color=palette[0],
        title='CAROLINA HURRICANES')
plt.show()

# %%
train = df.loc[df.season < 2022]
test = df.loc[df.season >= 2022]

fig, ax = plt.subplots(figsize=(15, 5))
train.plot(x='game_date', y='xGoalsPercentage', 
           ax=ax, label='Training Set', title='Data Train/Test Split')
test.plot(x='game_date', y='xGoalsPercentage',
          ax=ax, label='Test Set')
ax.axvline('2022-09-30', color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %%
df.loc[df.season == 2019] \
    .plot(x='game_date', y='xGoalsPercentage',
          figsize=(15, 5), title='Season Of Data')
plt.show()

# %%
df.info()
