# %%
from src.init_DFs.quick_init import *

# %% [markdown]
# # MASS INIT

# %%
season_arr = ['all', '20_22']
num_games_arr = [1, 2, 4, 8, 16, 32]
situation_arr = ['5on5']
groupby_cols = ["team", "season"]
include_null_next = True
include_null_targets = True
null_target_value = 2
target = "next_reg_win"
target_cols = ["reg_win"]
target_operations = []
auto_export = True
suffix=False
add_obj_cols=["season", "game_number", "is_home", "iceTime"]

res = quick_init__all(
    season_arr, situation_arr, num_games_arr, 
    groupby_cols,
    include_null_next, include_null_targets, null_target_value,
    target, target_cols, target_operations, 
    suffix, add_obj_cols, 
    auto_export
)

# %% [markdown]
# # PER GAME

# %%
season_arr = ['all', '20_22']
situation_arr = ['5on5']
auto_export = True

res = quick_init__per_game(season_arr, situation_arr, auto_export)

# %% [markdown]
# # ROLLING DB

# %%
season_arr = ['14_16', '17_19']
num_games_arr = [1, 2, 4, 8, 16, 32]
situation_arr = ['5on5']
groupby_cols = ["team", "season"]
include_null_next = True
include_null_targets = True
null_target_value = 2
target = "next_reg_win"
target_cols = ["reg_win"]
target_operations = []
auto_export = True

res = quick_init__rolling(season_arr, situation_arr, num_games_arr, groupby_cols,
                         include_null_next, include_null_targets, null_target_value,
                         target, target_cols, target_operations, auto_export)

# %% [markdown]
# # ROLLING SEASON DB

# %%
season_arr = ['all']
situation_arr = ['5on5']
suffix=False
add_obj_cols=["season", "game_number", "is_home", "iceTime"]
auto_export=True

res = quick_init__rolling_season(season_arr, situation_arr, suffix, add_obj_cols, auto_export)

# %% [markdown]
# # COMPARE ROLLINGS DB

# %% [markdown]
# # TRAJECTORY DB

# %% [markdown]
# # TEST

# %%
res[0].essentials
# Out:
#                 game_id team  season  score_1  opp_score_1  win_1  reg_win_1  \
# 0      2014-10-08BOSPHI  PHI    2014      1.0          2.0    0.0        0.0
# 1      2014-10-08BOSPHI  BOS    2014      2.0          1.0    1.0        1.0
# 2      2014-10-08CGYVAN  CGY    2014      2.0          4.0    0.0        0.0
# 3      2014-10-08CGYVAN  VAN    2014      4.0          2.0    1.0        1.0
# 4      2014-10-08LAKSJS  SJS    2014      4.0          0.0    1.0        1.0
# ...                 ...  ...     ...      ...          ...    ...        ...
# 21541  2023-04-13WSHNJD  NJD    2022      5.0          4.0    1.0        0.0
# 21542  2023-04-14CBJBUF  CBJ    2022      2.0          5.0    0.0        0.0
# 21543  2023-04-14CBJBUF  BUF    2022      5.0          2.0    1.0        1.0
# 21544  2023-04-14NSHCOL  COL    2022      4.0          3.0    1.0        1.0
# 21545  2023-04-14NSHCOL  NSH    2022      3.0          4.0    0.0        0.0
#
# ...
